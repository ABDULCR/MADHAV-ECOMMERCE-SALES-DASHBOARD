# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=np.arange(1,21).reshape(5,4)

# %%
gg=pd.DataFrame(df,index=['R1','R2','R3','R4','R5'],columns=['C1','C2','C3','C4'])

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5   6   7   8
# R3   9  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
def mahindra(x):
    x['INcome']=[100,200,300]
    return x
f=pd.DataFrame({'Name':['Vikash','Shyam','Kamlesh'],'INcome':[10,20,30]})
f.pipe(mahindra)
# Out:
#       Name  INcome
# 0   Vikash     100
# 1    Shyam     200
# 2  Kamlesh     300

# %%
def chng(l):
    l['Country']=['Dubai','us','Brazil']
p=pd.DataFrame({'Country':['Aman','Vinod','shyam'],'INcome':[10000,20000,3000]})
p.pipe(chng)

# %%
p
# Out:
#   Country  INcome
# 0   Dubai   10000
# 1      us   20000
# 2  Brazil    3000

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5   6   7   8
# R3   9  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
x=gg.agg(['sum','max'])

# %%
x
# Out:
#      C1  C2  C3  C4
# sum  45  50  55  60
# max  17  18  19  20

# %%
c=gg.aggregate(['sum'])

# %%
c
# Out:
#      C1  C2  C3  C4
# sum  45  50  55  60

# %%
ol=pd.read_csv('Diwali Sales Data.csv',encoding='unicode_escape')

# %%
ol
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0  \
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
ol.groupby('Gender').sum()
# Out:
#            User_ID                                          Cust_name
# Gender
# F       7865415150  SanskritiKartikBinduBalkShivangiGinnyKargatisE...  \
# M       3419388346  SudeviJoniJoniKushalHarshitaVasudevCanoPraneet...
#
#                                                Product_ID
# Gender
# F       P00125942P00110942P00118542P00018042P00273442P...  \
# M       P00237842P00057942P00057942P00205642P00200842P...
#
#                                                 Age Group     Age
# Gender
# F       26-3526-3526-3518-2555+26-3518-2518-2518-2546-...  277108  \
# M       0-1726-3526-3526-3526-3526-3546-5051-5551-5555...  121416
#
#         Marital_Status                                              State
# Gender
# F                 3266  MaharashtraAndhra PradeshUttar PradeshUttar Pr...  \
# M                 1463  KarnatakaGujaratHimachal PradeshUttar PradeshD...
#
#                                                      Zone
# Gender
# ...

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5   6   7   8
# R3   9  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
def ol(p):
    return p*8
gg.transform(ol)
# Out:
#      C1   C2   C3   C4
# R1    8   16   24   32
# R2   40   48   56   64
# R3   72   80   88   96
# R4  104  112  120  128
# R5  136  144  152  160

# %%
gg.truediv(3).round(2)
# Out:
#       C1    C2    C3    C4
# R1  0.33  0.67  1.00  1.33
# R2  1.67  2.00  2.33  2.67
# R3  3.00  3.33  3.67  4.00
# R4  4.33  4.67  5.00  5.33
# R5  5.67  6.00  6.33  6.67

# %%
ii= pd.DataFrame({"B": [0, 1, 2, np.nan, 4]})

# %%
ii
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  2.0
# 3  NaN
# 4  4.0

# %%
ii.expanding(1).sum()
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  3.0
# 3  3.0
# 4  7.0

# %%
gg.at['R2','C2']=-50

# %%
gg.at['R3','C1']=-30

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5 -50   7   8
# R3 -30  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
dq = pd.DataFrame({'B': [0, 1, 2, np.nan, 4]})

# %%
dq
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  2.0
# 3  NaN
# 4  4.0

# %%
dq.ewm(com=0.1).sum()
# Out:
#           B
# 0  0.000000
# 1  1.000000
# 2  2.090909
# 3  0.190083
# 4  4.017280

# %%
dq.ewm(alpha=2/3).mean()
# Out:
#           B
# 0  0.000000
# 1  0.750000
# 2  1.615385
# 3  1.615385
# 4  3.670213

# %%
dq.ewm(com=0.5,adjust=True).sum()
# Out:
#           B
# 0  0.000000
# 1  1.000000
# 2  2.333333
# 3  0.777778
# 4  4.259259

# %%
gg.abs()
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5  50   7   8
# R3  30  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
data = [[True, False, True], [True, True, True]]
df = pd.DataFrame(data)

# %%
df
# Out:
#       0      1     2
# 0  True  False  True
# 1  True   True  True

# %%
df.all()
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
df.any()
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
gg.clip(-35,15)
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5 -35   7   8
# R3 -30  10  11  12
# R4  13  14  15  15
# R5  15  15  15  15

# %%
gg.corrwith(gg)
# Out:
# C1    1.0
# C2    1.0
# C3    1.0
# C4    1.0
# dtype: float64

# %%
gg.count()
# Out:
# C1    5
# C2    5
# C3    5
# C4    5
# dtype: int64

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5 -50   7   8
# R3 -30  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
gg.cov(2)
# Out:
#        C1     C2    C3    C4
# C1  344.2  -13.2  40.0  40.0
# C2  -13.2  779.2  96.0  96.0
# C3   40.0   96.0  40.0  40.0
# C4   40.0   96.0  40.0  40.0

# %%
gg.cummax()
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5   2   7   8
# R3   5  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5 -50   7   8
# R3 -30  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
gg.cummin()
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   1 -50   3   4
# R3 -30 -50   3   4
# R4 -30 -50   3   4
# R5 -30 -50   3   4

# %%
gg.cumprod()
# Out:
#        C1      C2     C3      C4
# R1      1       2      3       4
# R2      5    -100     21      32
# R3   -150   -1000    231     384
# R4  -1950  -14000   3465    6144
# R5 -33150 -252000  65835  122880

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5 -50   7   8
# R3 -30  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
gg.cumprod()
# Out:
#        C1      C2     C3      C4
# R1      1       2      3       4
# R2      5    -100     21      32
# R3   -150   -1000    231     384
# R4  -1950  -14000   3465    6144
# R5 -33150 -252000  65835  122880

# %%
gg.cumsum()
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   6 -48  10  12
# R3 -24 -38  21  24
# R4 -11 -24  36  40
# R5   6  -6  55  60

# %%
gg.describe(include='all')
# Out:
#               C1         C2         C3         C4
# count   5.000000   5.000000   5.000000   5.000000
# mean    1.200000  -1.200000  11.000000  12.000000
# std    18.552628  27.914154   6.324555   6.324555
# min   -30.000000 -50.000000   3.000000   4.000000
# 25%     1.000000   2.000000   7.000000   8.000000
# 50%     5.000000  10.000000  11.000000  12.000000
# 75%    13.000000  14.000000  15.000000  16.000000
# max    17.000000  18.000000  19.000000  20.000000

# %%
data = [[10, 18, 11], [13, 15, 8], [9, 20, 3]]

# %%
gg.diff()
# Out:
#       C1    C2   C3   C4
# R1   NaN   NaN  NaN  NaN
# R2   4.0 -52.0  4.0  4.0
# R3 -35.0  60.0  4.0  4.0
# R4  43.0   4.0  4.0  4.0
# R5   4.0   4.0  4.0  4.0

# %%
gg
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   5 -50   7   8
# R3 -30  10  11  12
# R4  13  14  15  16
# R5  17  18  19  20

# %%
gg.eval('C2 + C3')
# Out:
# R1     5
# R2   -43
# R3    21
# R4    29
# R5    37
# dtype: int32

# %%
gg.eval('C1+ C4')
# Out:
# R1     5
# R2    13
# R3   -18
# R4    29
# R5    37
# dtype: int32

# %%
gg.max()
# Out:
# C1    17
# C2    18
# C3    19
# C4    20
# dtype: int32

# %%
gg.min()
# Out:
# C1   -30
# C2   -50
# C3     3
# C4     4
# dtype: int32

# %%
gg.mode()
# Out:
#    C1  C2  C3  C4
# 0 -30 -50   3   4
# 1   1   2   7   8
# 2   5  10  11  12
# 3  13  14  15  16
# 4  17  18  19  20

# %%
gg.median()
# Out:
# C1     5.0
# C2    10.0
# C3    11.0
# C4    12.0
# dtype: float64

# %%
gg.mode()
# Out:
#    C1  C2  C3  C4
# 0 -30 -50   3   4
# 1   1   2   7   8
# 2   5  10  11  12
# 3  13  14  15  16
# 4  17  18  19  20

# %%
gg.prod()
# Out:
# C1    -33150
# C2   -252000
# C3     65835
# C4    122880
# dtype: int32
